# %%
import numpy as np
import itertools as it
from scipy import optimize

# %%
import inspect
import re

def debug(x):
    frame = inspect.currentframe().f_back
    s = inspect.getframeinfo(frame).code_context[0]
    r = re.search(r"\((.*)\)", s).group(1)
    print("{} = \n{}\n".format(r,x))

# %%
DEBUG_SOLVER = False
DEBUG_BRUTEFORCE = True
DEBUG_POSSIBILITIES = True

# %%
#TODO faire tous les cas (si il n'y a pas de windturbine ou pas de kerosine plant
import json

with open('payload5.json', 'r') as f:
    data = json.load(f)

def pprint_powerplants(powerplants):
    for powerplant in powerplants:
        print(powerplant)
        
        
load = data['load']
fuels = data['fuels']
rejected = None # if there is a problem in data, we will save it here

debug(load)
debug(fuels)
print("powerplant:")
pprint_powerplants(data['powerplants'])
print("\n"*6)

def check_pmax_all_powerplants(powerplants):
    if load < get_sum_of_pmax(powerplants):
        return True
    else:
        return False
    

def get_sum_of_pmin(powerplants):
    sum=0
    for powerplant in powerplants:
        if powerplant['type'] == 'windturbine':
            sum+=powerplant['pmin']*fuels['wind(%)']/100 
        else:
            sum+=powerplant['pmin']
    return sum

def get_sum_of_pmax(powerplants):
    sum=0
    for powerplant in powerplants:
        if powerplant['type'] == 'windturbine':
            sum+=powerplant['pmax']*fuels['wind(%)']/100 
        else:
            sum+=powerplant['pmax']
    return sum

def solver(powerplants):
    
    #cost_gas = fuels['gas(euro/MWh)']
    #cost_kerosine = fuels['kerosine(euro/MWh)']
    #cost_co2 = fuels['co2(euro/ton)']
    #cost_wind = fuels['wind(%)']
    nplants = len(powerplants)

    c = []*nplants
    A_ub = [] # 2 "load" conditions and 2 boundary condition for each powerplant (pmin and pmax)
    b_ub =[]
    bounds=(0, None)



    #load conditions
    # (sum of p_i) <= load
    A_ub.append([1]*nplants)
    b_ub.append(load)

    # load <= (sum of p_i) ( -(sum of p_i) <= -load )
    A_ub.append([-1]*nplants)
    b_ub.append(-load)



    for i, powerplant in enumerate(powerplants): #i is the id of the powerplant
        if powerplant['type'] == 'gasfired':
            c.append(fuels['gas(euro/MWh)']/powerplant["efficiency"])

            pminConstraintA = [0]*nplants
            pminConstraintA[i] = -1
            pminConstraintb =  -powerplant['pmin']

            pmaxConstraintA = [0]*nplants
            pmaxConstraintA[i] = 1
            pmaxConstraintb =  powerplant['pmax']

            A_ub.append(pminConstraintA)
            A_ub.append(pmaxConstraintA)
            b_ub.append(pminConstraintb)
            b_ub.append(pmaxConstraintb)


        if powerplant['type'] == 'windturbine':
            c.append(0) #wind is free.

            pminConstraintA = [0]*nplants
            pminConstraintA[i] = -1
            pminConstraintb =  -powerplant['pmin']*fuels['wind(%)']/100 

            pmaxConstraintA = [0]*nplants
            pmaxConstraintA[i] = 1
            pmaxConstraintb =  powerplant['pmax']*fuels['wind(%)']/100

            A_ub.append(pminConstraintA)
            A_ub.append(pmaxConstraintA)
            b_ub.append(pminConstraintb)
            b_ub.append(pmaxConstraintb)
            #ne pas oublier de mettre faire rentrer le vent dans les boundaries

        if powerplant['type'] == 'turbojet':
            c.append(fuels['kerosine(euro/MWh)']/powerplant["efficiency"])

            pminConstraintA = [0]*nplants
            pminConstraintA[i] = -1
            pminConstraintb =  -powerplant['pmin']

            pmaxConstraintA = [0]*nplants
            pmaxConstraintA[i] = 1
            pmaxConstraintb =  powerplant['pmax']

            A_ub.append(pminConstraintA)
            A_ub.append(pmaxConstraintA)
            b_ub.append(pminConstraintb)
            b_ub.append(pmaxConstraintb)    
    
    solution = optimize.linprog(c = c,
                          A_ub = A_ub,
                          b_ub = b_ub,
                          bounds = bounds)['x']
    solution = np.around(solution, decimals = 1)
    price = np.dot(solution,c)
    
    if DEBUG_SOLVER:
        debug(A_ub)
        debug(b_ub)
        debug(c)
        debug(solution)
        debug(price)
    
    return solution, price
    
    
if check_pmax_all_powerplants(data['powerplants']):
    all_powerplants = data['powerplants']
    nall_powerplants = len(all_powerplants)

    best_possibility_by_combinations = [] #brute force combinaison to determine every combinations of powerplants
    for j in range(1,nall_powerplants+1):
        for powerplants in it.combinations(all_powerplants, j):
            if DEBUG_BRUTEFORCE:
                print("-----------------------------------------------------------")
                print("powerplants:")
            if get_sum_of_pmin(powerplants) <= load <= get_sum_of_pmax(powerplants): #reducing computation time
                if DEBUG_BRUTEFORCE:
                    pprint_powerplants(powerplants)
                best_possibility_by_combinations.append([powerplants,*solver(powerplants)])



    best_price = float('inf')
    best_possibility = None
    if DEBUG_POSSIBILITIES:
        print("price :")
    for possibility in best_possibility_by_combinations:
        price = possibility[2]
        if DEBUG_POSSIBILITIES:
            print(price)
        if price <= best_price:
            best_possibility = possibility
            best_price = price

    result = []
    for i, powerplant in enumerate(best_possibility[0]):
        result.append({'name':powerplant['name'], 'p': best_possibility[1][i]})

    debug(result)
else:
    print("Problem data : sum of pmax < load")
    print("load : ")
    print(load)
    print("sum_of_pmax : ")
    print(get_sum_of_pmax(data["powerplants"]))
# Out:
# load =
# 480
#
# fuels =
# {'gas(euro/MWh)': 13.4, 'kerosine(euro/MWh)': 50.8, 'co2(euro/ton)': 20, 'wind(%)': 0}
#
# powerplant:
# {'name': 'gasfiredbig2', 'type': 'gasfired', 'efficiency': 0.53, 'pmin': 100, 'pmax': 490}
# {'name': 'windpark1', 'type': 'windturbine', 'efficiency': 1, 'pmin': 0, 'pmax': 150}
# {'name': 'windpark2', 'type': 'windturbine', 'efficiency': 1, 'pmin': 0, 'pmax': 36}
#
#
#
#
#
#
#
# -----------------------------------------------------------
# powerplants:
# {'name': 'gasfiredbig2', 'type': 'gasfired', 'efficiency': 0.53, 'pmin': 100, 'pmax': 490}
# {'name': 'gasfiredbig2', 'type': 'gasfired', 'efficiency': 0.53, 'pmin': 100, 'pmax': 490}
# -----------------------------------------------------------
# powerplants:
# {'name': 'windpark1', 'type': 'windturbine', 'efficiency': 1, 'pmin': 0, 'pmax': 150}
# -----------------------------------------------------------
# powerplants:
# {'name': 'windpark2', 'type': 'windturbine', 'efficiency': 1, 'pmin': 0, 'pmax': 36}
# -----------------------------------------------------------
# powerplants:
# {'name': 'gasfiredbig2', 'type': 'gasfired', 'efficiency': 0.53, 'pmin': 100, 'pmax': 490}
# {'name': 'windpark1', 'type': 'windturbine', 'efficiency': 1, 'pmin': 0, 'pmax': 150}
# {'name': 'gasfiredbig2', 'type': 'gasfired', 'efficiency': 0.53, 'pmin': 100, 'pmax': 490}
# {'name': 'windpark1', 'type': 'windturbine', 'efficiency': 1, 'pmin': 0, 'pmax': 150}
# -----------------------------------------------------------
# powerplants:
# {'name': 'gasfiredbig2', 'type': 'gasfired', 'efficiency': 0.53, 'pmin': 100, 'pmax': 490}
# {'name': 'windpark2', 'type': 'windturbine', 'efficiency': 1, 'pmin': 0, 'pmax': 36}
# {'name': 'gasfiredbig2', 'type': 'gasfired', 'efficiency': 0.53, 'pmin': 100, 'pmax': 490}
# {'name': 'windpark2', 'type': 'windturbine', 'efficiency': 1, 'pmin': 0, 'pmax': 36}
# -----------------------------------------------------------
# powerplants:
# {'name': 'windpark1', 'type': 'windturbine', 'efficiency': 1, 'pmin': 0, 'pmax': 150}
# {'name': 'windpark2', 'type': 'windturbine', 'efficiency': 1, 'pmin': 0, 'pmax': 36}
# -----------------------------------------------------------
# powerplants:
# {'name': 'gasfiredbig2', 'type': 'gasfired', 'efficiency': 0.53, 'pmin': 100, 'pmax': 490}
# {'name': 'windpark1', 'type': 'windturbine', 'efficiency': 1, 'pmin': 0, 'pmax': 150}
# {'name': 'windpark2', 'type': 'windturbine', 'efficiency': 1, 'pmin': 0, 'pmax': 36}
# {'name': 'gasfiredbig2', 'type': 'gasfired', 'efficiency': 0.53, 'pmin': 100, 'pmax': 490}
# {'name': 'windpark1', 'type': 'windturbine', 'efficiency': 1, 'pmin': 0, 'pmax': 150}
# {'name': 'windpark2', 'type': 'windturbine', 'efficiency': 1, 'pmin': 0, 'pmax': 36}
# price :
# 12135.849056603774
# 12135.849056603774
# 12135.849056603774
# 12135.849056603774
# result =
# [{'name': 'gasfiredbig2', 'p': 480.0}, {'name': 'windpark1', 'p': 0.0}, {'name': 'windpark2', 'p': 0.0}]

# %%
print(np.array(A_ub))
print(np.array(b_ub))
print(c)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-55-bd593d6e196e> in <module>
# ----> 1 print(np.array(A_ub))
#       2 print(np.array(b_ub))
#       3 print(c)
#
# NameError: name 'A_ub' is not defined

# %%
solution = optimize.linprog(c = c,
                          A_ub = A_ub,
                          b_ub = b_ub,
                          bounds = bounds)['x']
solution = np.around(solution, decimals = 1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-54-e936517346d4> in <module>
# ----> 1 solution = optimize.linprog(c = c,
#       2                           A_ub = A_ub,
#       3                           b_ub = b_ub,
#       4                           bounds = bounds)['x']
#       5 solution = np.around(solution, decimals = 1)
#
# NameError: name 'c' is not defined

# %%
print(solution)
print(c)
np.dot(solution,c)
# Out:
# [ 10. 100.]
# [0, 25.28301886792453]
# 2528.301886792453

# %%
result = []
for i, powerplant in enumerate(powerplants):
    result.append({'name':powerplant['name'], 'p': solution[i]})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-52-3422ec860e1f> in <module>
#       1 result = []
#       2 for i, powerplant in enumerate(powerplants):
# ----> 3     result.append({'name':powerplant['name'], 'p': solution[i]})
#
# NameError: name 'solution' is not defined

# %%
# Objective Function: 50x_1 + 80x_2
# Constraint 1: 5x_1 + 2x_2 <= 20
# Constraint 2: -10x_1 + -12x_2 <= -90

result = optimize.linprog(
    c = [50, 80],  # Cost function: 50x_1 + 80x_2
    A_ub = [[5, 2], 
          [1, 0],
          [-1, 0],
          [0, 1],
          [0, -1],
         ],  # Coefficients for inequalities
    b_ub = [20, 
          10,
          0,
          5,
          0
         ],  # Constraints for inequalities: 20 and -90
    bounds=(0, None), # Bounds on x, 0 <= x_i <= +oo by default
)

print(result)
50*result.x[0] + 80*result.x[1]
